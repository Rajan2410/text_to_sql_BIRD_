# %%
# !pip install premsql
# Out:
# Collecting premsql
#   Downloading premsql-0.1.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=2.0.30 in /usr/local/lib/python3.10/dist-packages (from premsql) (2.0.34)
# Collecting black<25.0.0,>=24.4.2 (from premsql)
#   Downloading black-24.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 2.0 MB/s eta 0:00:00
# Collecting datasets<3.0.0,>=2.20.0 (from premsql)
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: einops<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from premsql) (0.8.0)
# Collecting fastapi<0.113.0,>=0.112.0 (from premsql)
#   Downloading fastapi-0.112.4-py3-none-any.whl.metadata (27 kB)
# Collecting func_timeout<5.0.0,>=4.3.5 (from premsql)
#   Downloading func_timeout-4.3.5.tar.gz (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: huggingface-hub<0.25.0,>=0.24.5 in /usr/local/lib/python3.10/dist-packages (from premsql) (0.24.6)
# Collecting isort<6.0.0,>=5.13.2 (from premsql)
#   Downloading isort-5.13.2-py3-none-any.whl.metadata (12 kB)
# Collecting langchain<0.3.0,>=0.2.16 (from premsql)
#   Downloading langchain-0.2.16-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-community<0.3.0,>=0.2.16 (from premsql)
#   Downloading langchain_community-0.2.17-py3-none-any.whl.metadata (2.7 kB)
# Collecting mysql-connector-python<10.0.0,>=9.0.0 (from premsql)
#   Downloading mysql_connector_python-9.0.0-cp310-cp310-manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.26.3 in /usr/local/lib/python3.10/dist-packages (from premsql) (1.26.4)
# Collecting premai<0.4.0,>=0.3.64 (from premsql)
#   Downloading premai-0.3.69-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: sqlparse<0.6.0,>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from premsql) (0.5.1)
# Requirement already satisfied: torch<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from premsql) (2.4.0+cu121)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.4 in /usr/local/lib/python3.10/dist-packages (from premsql) (4.66.5)
# Requirement already satisfied: transformers<5.0.0,>=4.43.3 in /usr/local/lib/python3.10/dist-packages (from premsql) (4.44.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black<25.0.0,>=24.4.2->premsql) (8.1.7)
# Collecting mypy-extensions>=0.4.3 (from black<25.0.0,>=24.4.2->premsql)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.10/dist-packages (from black<25.0.0,>=24.4.2->premsql) (24.1)
# Collecting pathspec>=0.9.0 (from black<25.0.0,>=24.4.2->premsql)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black<25.0.0,>=24.4.2->premsql) (4.3.2)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black<25.0.0,>=24.4.2->premsql) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from black<25.0.0,>=24.4.2->premsql) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.20.0->premsql) (3.16.0)
# Collecting pyarrow>=15.0.0 (from datasets<3.0.0,>=2.20.0->premsql)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets<3.0.0,>=2.20.0->premsql)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.20.0->premsql) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.20.0->premsql) (2.32.3)
# Collecting xxhash (from datasets<3.0.0,>=2.20.0->premsql)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets<3.0.0,>=2.20.0->premsql)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets<3.0.0,>=2.20.0->premsql) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.20.0->premsql) (3.10.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.20.0->premsql) (6.0.2)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi<0.113.0,>=0.112.0->premsql)
#   Downloading starlette-0.38.5-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from fastapi<0.113.0,>=0.112.0->premsql) (2.9.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.16->premsql) (4.0.3)
# Collecting langchain-core<0.3.0,>=0.2.38 (from langchain<0.3.0,>=0.2.16->premsql)
#   Downloading langchain_core-0.2.40-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain<0.3.0,>=0.2.16->premsql)
#   Downloading langchain_text_splitters-0.2.4-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain<0.3.0,>=0.2.16->premsql)
#   Downloading langsmith-0.1.120-py3-none-any.whl.metadata (13 kB)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain<0.3.0,>=0.2.16->premsql)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community<0.3.0,>=0.2.16->premsql)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: attrs>=21.3.0 in /usr/local/lib/python3.10/dist-packages (from premai<0.4.0,>=0.3.64->premsql) (24.2.0)
# Collecting httpx<0.27.0,>=0.20.0 (from premai<0.4.0,>=0.3.64->premsql)
#   Downloading httpx-0.26.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from premai<0.4.0,>=0.3.64->premsql) (2.8.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3.0.0,>=2.0.30->premsql) (3.1.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.2.0->premsql) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.2.0->premsql) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.2.0->premsql) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.43.3->premsql) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.43.3->premsql) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.43.3->premsql) (0.19.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.20.0->premsql) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.20.0->premsql) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.20.0->premsql) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.20.0->premsql) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.20.0->premsql) (1.11.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.16->premsql)
#   Downloading marshmallow-3.22.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.16->premsql)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<0.27.0,>=0.20.0->premai<0.4.0,>=0.3.64->premsql) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<0.27.0,>=0.20.0->premai<0.4.0,>=0.3.64->premsql) (2024.8.30)
# Collecting httpcore==1.* (from httpx<0.27.0,>=0.20.0->premai<0.4.0,>=0.3.64->premsql)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<0.27.0,>=0.20.0->premai<0.4.0,>=0.3.64->premsql) (3.8)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<0.27.0,>=0.20.0->premai<0.4.0,>=0.3.64->premsql) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<0.27.0,>=0.20.0->premai<0.4.0,>=0.3.64->premsql)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.38->langchain<0.3.0,>=0.2.16->premsql)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain<0.3.0,>=0.2.16->premsql)
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<0.113.0,>=0.112.0->premsql) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<0.113.0,>=0.112.0->premsql) (2.23.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.8.0->premai<0.4.0,>=0.3.64->premsql) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets<3.0.0,>=2.20.0->premsql) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets<3.0.0,>=2.20.0->premsql) (2.0.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<3.0.0,>=2.2.0->premsql) (2.1.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets<3.0.0,>=2.20.0->premsql) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets<3.0.0,>=2.20.0->premsql) (2024.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<3.0.0,>=2.2.0->premsql) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<0.27.0,>=0.20.0->premai<0.4.0,>=0.3.64->premsql) (1.2.2)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.38->langchain<0.3.0,>=0.2.16->premsql)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Downloading premsql-0.1.1-py3-none-any.whl (36 kB)
# Downloading black-24.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 22.9 MB/s eta 0:00:00
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 10.2 MB/s eta 0:00:00
# Downloading fastapi-0.112.4-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 6.9 MB/s eta 0:00:00
# Downloading isort-5.13.2-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.3/92.3 kB 5.5 MB/s eta 0:00:00
# Downloading langchain-0.2.16-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 21.2 MB/s eta 0:00:00
# Downloading langchain_community-0.2.17-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 24.5 MB/s eta 0:00:00
# Downloading mysql_connector_python-9.0.0-cp310-cp310-manylinux_2_17_x86_64.whl (19.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 32.8 MB/s eta 0:00:00
# Downloading premai-0.3.69-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 kB 4.8 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.9 MB/s eta 0:00:00
# Downloading httpx-0.26.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 2.7 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.0 MB/s eta 0:00:00
# Downloading langchain_core-0.2.40-py3-none-any.whl (396 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.0/397.0 kB 8.6 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.2.4-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.120-py3-none-any.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.8/289.8 kB 12.5 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 14.9 MB/s eta 0:00:00
# Downloading starlette-0.38.5-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 3.4 MB/s eta 0:00:00
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 5.6 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.2 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 1.8 MB/s eta 0:00:00
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 9.7 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.9 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Building wheels for collected packages: func_timeout
#   Building wheel for func_timeout (setup.py) ... done
#   Created wheel for func_timeout: filename=func_timeout-4.3.5-py3-none-any.whl size=15077 sha256=609d316ffd606a87dcfff18fb6920ec672adf797364ade945d0c5562e107cccc
#   Stored in directory: /root/.cache/pip/wheels/3f/83/19/b5552bb9630e353f7c5b15be44bf10900afe1abbbfcf536afd
# Successfully built func_timeout
# Installing collected packages: func_timeout, xxhash, tenacity, pyarrow, pathspec, orjson, mysql-connector-python, mypy-extensions, marshmallow, jsonpointer, isort, h11, dill, typing-inspect, starlette, multiprocess, jsonpatch, httpcore, black, httpx, fastapi, dataclasses-json, premai, langsmith, langchain-core, datasets, langchain-text-splitters, langchain, langchain-community, premsql
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed black-24.8.0 dataclasses-json-0.6.7 datasets-2.21.0 dill-0.3.8 fastapi-0.112.4 func_timeout-4.3.5 h11-0.14.0 httpcore-1.0.5 httpx-0.26.0 isort-5.13.2 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.16 langchain-community-0.2.17 langchain-core-0.2.40 langchain-text-splitters-0.2.4 langsmith-0.1.120 marshmallow-3.22.0 multiprocess-0.70.16 mypy-extensions-1.0.0 mysql-connector-python-9.0.0 orjson-3.10.7 pathspec-0.12.1 premai-0.3.69 premsql-0.1.1 pyarrow-17.0.0 starlette-0.38.5 tenacity-8.5.0 typing-inspect-0.9.0 xxhash-3.5.0

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.21.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.24.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
from premsql.datasets import Text2SQLDataset

# %%
import sqlite3
from transformers import pipeline
import sqlglot
import json
from datasets import load_dataset
import random

# %%
bird_test_dataset = Text2SQLDataset( dataset_name='bird',split='validation', force_download=False, dataset_folder="/root/anindya/text2sql/data")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 167 files:   0%|          | 0/167 [00:00<?, ?it/s]
# train/train_databases/address/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/8.04k [00:00<?, ?B/s]
# train/train_databases/airline/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# train/train_databases/.DS_Store:   0%|          | 0.00/26.6k [00:00<?, ?B/s]
# train/train.json:   0%|          | 0.00/4.32M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/333 [00:00<?, ?B/s]
# airline.sqlite:   0%|          | 0.00/123M [00:00<?, ?B/s]
# address.sqlite:   0%|          | 0.00/26.6M [00:00<?, ?B/s]
# (…)rain/train_databases/app_store/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# train/train_databases/authors/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)n/train_databases/beer_factory/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# authors.sqlite:   0%|          | 0.00/616M [00:00<?, ?B/s]
# app_store.sqlite:   0%|          | 0.00/18.0M [00:00<?, ?B/s]
# (…)tabases/beer_factory/beer_factory.sqlite:   0%|          | 0.00/991k [00:00<?, ?B/s]
# (…)n/train_databases/bike_share_1/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)abases/book_publishing_company/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)g_company/book_publishing_company.sqlite:   0%|          | 0.00/184k [00:00<?, ?B/s]
# bike_share_1.sqlite:   0%|          | 0.00/5.21G [00:00<?, ?B/s]
# train/train_databases/books/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)in/train_databases/car_retails/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# books.sqlite:   0%|          | 0.00/4.34M [00:00<?, ?B/s]
# (…)databases/car_retails/car_retails.sqlite:   0%|          | 0.00/487k [00:00<?, ?B/s]
# train/train_databases/cars/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# train/train_databases/cars/cars.sqlite:   0%|          | 0.00/135k [00:00<?, ?B/s]
# (…)/train_databases/chicago_crime/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# train/train_databases/citeseer/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)in_databases/codebase_comments/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)/train_databases/coinmarketcap/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# chicago_crime.sqlite:   0%|          | 0.00/66.7M [00:00<?, ?B/s]
# citeseer.sqlite:   0%|          | 0.00/7.43M [00:00<?, ?B/s]
# codebase_comments.sqlite:   0%|          | 0.00/4.50G [00:00<?, ?B/s]
# coinmarketcap.sqlite:   0%|          | 0.00/1.51G [00:00<?, ?B/s]
# (…)n_databases/college_completion/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# college_completion.sqlite:   0%|          | 0.00/71.2M [00:00<?, ?B/s]
# (…)ain_databases/computer_student/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)computer_student/computer_student.sqlite:   0%|          | 0.00/45.1k [00:00<?, ?B/s]
# train/train_databases/cookbook/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)rain/train_databases/craftbeer/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)ain_databases/craftbeer/craftbeer.sqlite:   0%|          | 0.00/442k [00:00<?, ?B/s]
# cookbook.sqlite:   0%|          | 0.00/1.22M [00:00<?, ?B/s]
# (…)in/train_databases/cs_semester/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)databases/cs_semester/cs_semester.sqlite:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# train/train_databases/disney/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)ain/train_databases/disney/disney.sqlite:   0%|          | 0.00/258k [00:00<?, ?B/s]
# train/train_databases/donor/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# donor.sqlite:   0%|          | 0.00/4.50G [00:00<?, ?B/s]
# (…)_databases/european_football_1/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# european_football_1.sqlite:   0%|          | 0.00/11.9M [00:00<?, ?B/s]
# (…)rain_databases/food_inspection/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# food_inspection.sqlite:   0%|          | 0.00/5.02M [00:00<?, ?B/s]
# (…)in_databases/food_inspection_2/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# food_inspection_2.sqlite:   0%|          | 0.00/217M [00:00<?, ?B/s]
# train/train_databases/genes/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# genes.sqlite:   0%|          | 0.00/1.53M [00:00<?, ?B/s]
# train/train_databases/hockey/.DS_Store:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# hockey.sqlite:   0%|          | 0.00/6.89M [00:00<?, ?B/s]
# (…)rain_databases/human_resources/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)s/human_resources/human_resources.sqlite:   0%|          | 0.00/28.7k [00:00<?, ?B/s]
# (…)ain_databases/ice_hockey_draft/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# ice_hockey_draft.sqlite:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# (…)n_databases/image_and_language/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# image_and_language.sqlite:   0%|          | 0.00/139M [00:00<?, ?B/s]
# (…)rain_databases/language_corpus/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# language_corpus.sqlite:   0%|          | 0.00/2.38G [00:00<?, ?B/s]
# (…)in/train_databases/law_episode/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)databases/law_episode/law_episode.sqlite:   0%|          | 0.00/549k [00:00<?, ?B/s]
# (…)ain/train_databases/legislator/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# legislator.sqlite:   0%|          | 0.00/3.49M [00:00<?, ?B/s]
# (…)databases/mental_health_survey/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# mental_health_survey.sqlite:   0%|          | 0.00/18.3M [00:00<?, ?B/s]
# train/train_databases/menu/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# menu.sqlite:   0%|          | 0.00/272M [00:00<?, ?B/s]
# (…)in/train_databases/mondial_geo/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# mondial_geo.sqlite:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# train/train_databases/movie/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# movie.sqlite:   0%|          | 0.00/1.57M [00:00<?, ?B/s]
# train/train_databases/movie_3/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# movie_3.sqlite:   0%|          | 0.00/6.36M [00:00<?, ?B/s]
# (…)train_databases/movie_platform/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# movie_platform.sqlite:   0%|          | 0.00/4.31G [00:00<?, ?B/s]
# (…)rain/train_databases/movielens/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# movielens.sqlite:   0%|          | 0.00/85.8M [00:00<?, ?B/s]
# train/train_databases/movies_4/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# movies_4.sqlite:   0%|          | 0.00/13.1M [00:00<?, ?B/s]
# (…)ain_databases/music_platform_2/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# music_platform_2.sqlite:   0%|          | 0.00/1.55G [00:00<?, ?B/s]
# (…)/train_databases/music_tracker/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# music_tracker.sqlite:   0%|          | 0.00/15.2M [00:00<?, ?B/s]
# train/train_databases/olympics/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# olympics.sqlite:   0%|          | 0.00/18.1M [00:00<?, ?B/s]
# (…)abases/professional_basketball/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# professional_basketball.sqlite:   0%|          | 0.00/6.67M [00:00<?, ?B/s]
# (…)tabases/public_review_platform/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# public_review_platform.sqlite:   0%|          | 0.00/65.3M [00:00<?, ?B/s]
# (…)train_databases/regional_sales/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# regional_sales.sqlite:   0%|          | 0.00/2.28M [00:00<?, ?B/s]
# (…)ain/train_databases/restaurant/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)n_databases/restaurant/restaurant.sqlite:   0%|          | 0.00/807k [00:00<?, ?B/s]
# (…)ain_databases/retail_complains/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# retail_complains.sqlite:   0%|          | 0.00/25.1M [00:00<?, ?B/s]
# (…)n/train_databases/retail_world/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)tabases/retail_world/retail_world.sqlite:   0%|          | 0.00/65.5k [00:00<?, ?B/s]
# train/train_databases/retails/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# retails.sqlite:   0%|          | 0.00/1.03G [00:00<?, ?B/s]
# train/train_databases/sales/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# sales.sqlite:   0%|          | 0.00/130M [00:00<?, ?B/s]
# (…)ain_databases/sales_in_weather/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# sales_in_weather.sqlite:   0%|          | 0.00/464M [00:00<?, ?B/s]
# (…)in/train_databases/shakespeare/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# shakespeare.sqlite:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# train/train_databases/shipping/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)train_databases/shipping/shipping.sqlite:   0%|          | 0.00/131k [00:00<?, ?B/s]
# train/train_databases/shooting/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)train_databases/shooting/shooting.sqlite:   0%|          | 0.00/180k [00:00<?, ?B/s]
# (…)ain_databases/simpson_episodes/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)simpson_episodes/simpson_episodes.sqlite:   0%|          | 0.00/754k [00:00<?, ?B/s]
# (…)in/train_databases/soccer_2016/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# soccer_2016.sqlite:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# (…)n/train_databases/social_media/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# social_media.sqlite:   0%|          | 0.00/69.1M [00:00<?, ?B/s]
# (…)ain_databases/software_company/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# software_company.sqlite:   0%|          | 0.00/342M [00:00<?, ?B/s]
# (…)n/train_databases/student_loan/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)tabases/student_loan/student_loan.sqlite:   0%|          | 0.00/307k [00:00<?, ?B/s]
# (…)ain/train_databases/superstore/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# superstore.sqlite:   0%|          | 0.00/6.63M [00:00<?, ?B/s]
# train/train_databases/synthea/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# synthea.sqlite:   0%|          | 0.00/38.6M [00:00<?, ?B/s]
# (…)in/train_databases/talkingdata/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# talkingdata.sqlite:   0%|          | 0.00/1.90G [00:00<?, ?B/s]
# train/train_databases/train_tables.json:   0%|          | 0.00/726k [00:00<?, ?B/s]
# train/train_databases/trains/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# trains.sqlite:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# (…)ain/train_databases/university/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)n_databases/university/university.sqlite:   0%|          | 0.00/631k [00:00<?, ?B/s]
# (…)in/train_databases/video_games/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# video_games.sqlite:   0%|          | 0.00/2.55M [00:00<?, ?B/s]
# (…)n/train_databases/works_cycles/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# works_cycles.sqlite:   0%|          | 0.00/115M [00:00<?, ?B/s]
# train/train_databases/world/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# train/train_databases/world/world.sqlite:   0%|          | 0.00/254k [00:00<?, ?B/s]
# (…)s/world_development_indicators/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# world_development_indicators.sqlite:   0%|          | 0.00/2.45G [00:00<?, ?B/s]
# validation/dev_databases/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)v_databases/california_schools/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# california_schools.sqlite:   0%|          | 0.00/11.1M [00:00<?, ?B/s]
# (…)ation/dev_databases/card_games/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# card_games.sqlite:   0%|          | 0.00/262M [00:00<?, ?B/s]
# (…)v_databases/codebase_community/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# codebase_community.sqlite:   0%|          | 0.00/481M [00:00<?, ?B/s]
# (…)abases/debit_card_specializing/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# debit_card_specializing.sqlite:   0%|          | 0.00/34.6M [00:00<?, ?B/s]
# (…)_databases/european_football_2/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# european_football_2.sqlite:   0%|          | 0.00/598M [00:00<?, ?B/s]
# (…)dation/dev_databases/financial/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# financial.sqlite:   0%|          | 0.00/71.3M [00:00<?, ?B/s]
# (…)dation/dev_databases/formula_1/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# formula_1.sqlite:   0%|          | 0.00/22.4M [00:00<?, ?B/s]
# (…)ion/dev_databases/student_club/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# student_club.sqlite:   0%|          | 0.00/2.64M [00:00<?, ?B/s]
# (…)dation/dev_databases/superhero/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# (…)dev_databases/superhero/superhero.sqlite:   0%|          | 0.00/238k [00:00<?, ?B/s]
# (…)atabases/thrombosis_prediction/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# thrombosis_prediction.sqlite:   0%|          | 0.00/7.33M [00:00<?, ?B/s]
# (…)ation/dev_databases/toxicology/.DS_Store:   0%|          | 0.00/6.15k [00:00<?, ?B/s]
# toxicology.sqlite:   0%|          | 0.00/2.68M [00:00<?, ?B/s]
# validation/validation.json:   0%|          | 0.00/741k [00:00<?, ?B/s]
# 2024-09-16 05:16:17,002 - [BIRD-DATASET] - INFO - Loaded Bird Dataset
# INFO:[BIRD-DATASET]:Loaded Bird Dataset

# %%
bird_test_dataset = bird_test_dataset.setup_dataset()
# Out:
# 2024-09-16 05:20:21,169 - [BIRD-DATASET] - INFO - Setting up Bird Dataset
# INFO:[BIRD-DATASET]:Setting up Bird Dataset
# Applying prompt:   0%|          | 0/1534 [00:00<?, ?it/s]

# %%
bird_test_dataset[0]
# Out:
# {'question_id': 0,
#  'db_id': 'california_schools',
#  'question': 'What is the highest eligible free rate for K-12 students in the schools in Alameda County?',
#  'evidence': 'Eligible free rate for K-12 = `Free Meal Count (K-12)` / `Enrollment (K-12)`',
#  'SQL': "SELECT `Free Meal Count (K-12)` / `Enrollment (K-12)` FROM frpm WHERE `County Name` = 'Alameda' ORDER BY (CAST(`Free Meal Count (K-12)` AS REAL) / `Enrollment (K-12)`) DESC LIMIT 1",
#  'difficulty': 'simple',
#  'db_path': '/root/anindya/text2sql/data/bird/validation/dev_databases/california_schools/california_schools.sqlite',
#  'prompt': '\n# Follow these instruction:\nYou will be given schemas of tables of a database. Your job is to write correct\nerror free SQL query based on the question asked. Please make sure:\n\n1. Do not add ``` at start / end of the query. It should be a single line query in a  single line (string format)\n2. Make sure the column names are correct and exists in the table\n3. For column names which has a space with it, make sure you have put `` in that column name\n4. Think step by step and always check schema and question and the column names before writing the\nquery. \n\n# Database and Table Schema:\nCREATE TABLE frpm\n(\n    CDSCode                                       TEXT not null\n        primary key,\n    `Academic Year`                               TEXT  null,\n    `County Code`                                 TEXT  null,\n    `District Code`                               INTEGER         null,\n    `School Code`                                 TEXT  null,\n    `County Name`                                 TEXT null,\n    `District Name`                               TEXT null,\n    `School Name`                                 TEXT null,\n    `District Type`                               TEXT null,\n    `School Type`                                 TEXT null,\n    `Educational Option Type`                     TEXT null,\n    `NSLP Provision Status`                       TEXT null,\n    `Charter School (Y/N)`                        INTEGER    null,\n    `Charter School Number`                       TEXT  null,\n    `Charter Funding Type`                        TEXT null,\n    IRC                                           INTEGER    null,\n    `Low Grade`                                   TEXT  null,\n    `High Grade`                                  TEXT null,\n    `Enrollment (K-12)`                           REAL      null,\n    `Free Meal Count (K-12)`                      REAL       null,\n    `Percent (%) Eligible Free (K-12)`            REAL       null,\n    `FRPM Count (K-12)`                           REAL       null,\n    `Percent (%) Eligible FRPM (K-12)`            REAL       null,\n    `Enrollment (Ages 5-17)`                      REAL       null,\n    `Free Meal Count (Ages 5-17)`                 REAL       null,\n    `Percent (%) Eligible Free (Ages 5-17)`       REAL       null,\n    `FRPM Count (Ages 5-17)`                      REAL       null,\n    `Percent (%) Eligible FRPM (Ages 5-17)`       REAL       null,\n    `2013-14 CALPADS Fall 1 Certification Status` INTEGER    null,\n    foreign key (CDSCode) references schools (CDSCode)\n)\nCREATE TABLE satscores\n(\n    cds         TEXT not null\n        primary key,\n    rtype       TEXT  not null,\n    sname       TEXT null,\n    dname       TEXT null,\n    cname       TEXT null,\n    enroll12    INTEGER         not null,\n    NumTstTakr  INTEGER          not null,\n    AvgScrRead  INTEGER          null,\n    AvgScrMath  INTEGER          null,\n    AvgScrWrite INTEGER          null,\n    NumGE1500   INTEGER          null,\n--     PctGE1500   double      null,\n        foreign key (cds) references schools (CDSCode)\n)\nCREATE TABLE schools\n(\n    CDSCode     TEXT not null\n        primary key,\n    NCESDist    TEXT  null,\n    NCESSchool  TEXT  null,\n    StatusType  TEXT  not null,\n    County      TEXT not null,\n    District    TEXT not null,\n    School      TEXT null,\n    Street      TEXT null,\n    StreetAbr   TEXT null,\n    City        TEXT null,\n    Zip         TEXT null,\n    State       TEXT  null,\n    MailStreet  TEXT null,\n    MailStrAbr  TEXT null,\n    MailCity    TEXT null,\n    MailZip     TEXT null,\n    MailState   TEXT  null,\n    Phone       TEXT null,\n    Ext         TEXT  null,\n    Website     TEXT null,\n    OpenDate    DATE        null,\n    ClosedDate  DATE        null,\n    Charter     INTEGER    null,\n    CharterNum  TEXT  null,\n    FundingType TEXT null,\n    DOC         TEXT  not null,\n    DOCType     TEXT not nul ...

# %%
raw_bird_test_ds = bird_test_dataset.raw_dataset

# %%
first_data= raw_bird_test_ds[0]
first_data['prompt']
# Out:
# '\n# Follow these instruction:\nYou will be given schemas of tables of a database. Your job is to write correct\nerror free SQL query based on the question asked. Please make sure:\n\n1. Do not add ``` at start / end of the query. It should be a single line query in a  single line (string format)\n2. Make sure the column names are correct and exists in the table\n3. For column names which has a space with it, make sure you have put `` in that column name\n4. Think step by step and always check schema and question and the column names before writing the\nquery. \n\n# Database and Table Schema:\nCREATE TABLE frpm\n(\n    CDSCode                                       TEXT not null\n        primary key,\n    `Academic Year`                               TEXT  null,\n    `County Code`                                 TEXT  null,\n    `District Code`                               INTEGER         null,\n    `School Code`                                 TEXT  null,\n    `County Name`                                 TEXT null,\n    `District Name`                               TEXT null,\n    `School Name`                                 TEXT null,\n    `District Type`                               TEXT null,\n    `School Type`                                 TEXT null,\n    `Educational Option Type`                     TEXT null,\n    `NSLP Provision Status`                       TEXT null,\n    `Charter School (Y/N)`                        INTEGER    null,\n    `Charter School Number`                       TEXT  null,\n    `Charter Funding Type`                        TEXT null,\n    IRC                                           INTEGER    null,\n    `Low Grade`                                   TEXT  null,\n    `High Grade`                                  TEXT null,\n    `Enrollment (K-12)`                           REAL      null,\n    `Free Meal Count (K-12)`                      REAL       null,\n    `Percent (%) Eligible Free (K-12)`            REAL       null,\n    `FRPM Count (K-12)`                           REAL       null,\n    `Percent (%) Eligible FRPM (K-12)`            REAL       null,\n    `Enrollment (Ages 5-17)`                      REAL       null,\n    `Free Meal Count (Ages 5-17)`                 REAL       null,\n    `Percent (%) Eligible Free (Ages 5-17)`       REAL       null,\n    `FRPM Count (Ages 5-17)`                      REAL       null,\n    `Percent (%) Eligible FRPM (Ages 5-17)`       REAL       null,\n    `2013-14 CALPADS Fall 1 Certification Status` INTEGER    null,\n    foreign key (CDSCode) references schools (CDSCode)\n)\nCREATE TABLE satscores\n(\n    cds         TEXT not null\n        primary key,\n    rtype       TEXT  not null,\n    sname       TEXT null,\n    dname       TEXT null,\n    cname       TEXT null,\n    enroll12    INTEGER         not null,\n    NumTstTakr  INTEGER          not null,\n    AvgScrRead  INTEGER          null,\n    AvgScrMath  INTEGER          null,\n    AvgScrWrite INTEGER          null,\n    NumGE1500   INTEGER          null,\n--     PctGE1500   double      null,\n        foreign key (cds) references schools (CDSCode)\n)\nCREATE TABLE schools\n(\n    CDSCode     TEXT not null\n        primary key,\n    NCESDist    TEXT  null,\n    NCESSchool  TEXT  null,\n    StatusType  TEXT  not null,\n    County      TEXT not null,\n    District    TEXT not null,\n    School      TEXT null,\n    Street      TEXT null,\n    StreetAbr   TEXT null,\n    City        TEXT null,\n    Zip         TEXT null,\n    State       TEXT  null,\n    MailStreet  TEXT null,\n    MailStrAbr  TEXT null,\n    MailCity    TEXT null,\n    MailZip     TEXT null,\n    MailState   TEXT  null,\n    Phone       TEXT null,\n    Ext         TEXT  null,\n    Website     TEXT null,\n    OpenDate    DATE        null,\n    ClosedDate  DATE        null,\n    Charter     INTEGER    null,\n    CharterNum  TEXT  null,\n    FundingType TEXT null,\n    DOC         TEXT  not null,\n    DOCType     TEXT not null,\n    SOC ...

# %%
len(raw_bird_test_ds)
# Out:
# 1534

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="premai-io/prem-1B-SQL", truncation=True, max_new_tokens=512)
# Out:
# Unrecognized keys in `rope_scaling` for 'rope_type'='linear': {'type'}
# Unrecognized keys in `rope_scaling` for 'rope_type'='linear': {'type'}
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
import json
from pathlib import Path
from premsql.evaluator import Text2SQLEvaluator

# %%
from premsql.executors import SQLiteExecutor

# %%
def generate_sql_from_text(nl_prompt):
    prompt = nl_prompt
    generated = generator(prompt)[0]['generated_text']

    sql_start = generated.find('SELECT')
    sql_query = generated[sql_start:].strip()

    if ";" in sql_query:
        sql_query = sql_query.split(";")[0].strip()+';'

    if "\n\n\n" in sql_query:
        sql_query = sql_query.split("\n\n\n")[-1].strip()

    if '$$ LANGUAGE plpgsql;' in sql_query:
        parts = sql_query.split('$$ LANGUAGE plpgsql;')
        for part in parts:
          part=part.strip()
          if part.startswith('SELECT'):
            print('part-1')
            sql_query = part
            break

    #print('Generated SQL is:\n',sql_query)
    return sql_query

# %%
def validate_sql(query):
    try:
        sqlglot.parse_one(query)
        return True, "Valid SQL"
    except Exception as e:
        return False, str(e)

# %%
def execute_query(db_id,sql_query):
  print(f'Executing query in {db_id}')
  executor = SQLiteExecutor()
  db_path = (
    f"/root/anindya/text2sql/data/bird/validation/dev_databases/{db_id}/{db_id}.sqlite"
  )
  sql = sql_query

  result = executor.execute_sql(
    sql=sql,
    dsn_or_db_path=db_path
  )

  return result

# %%
import random

def evaluate_bird_benchmark():
    # Picking a random example from the dataset
    random_example = random.choice(bird_test_dataset)

    # Extracting nl nd sql
    nl_query = random_example['question']
    nl_prompt= random_example['prompt']
    evidence = random_example['evidence']
    db_id = random_example['db_id']
    expected_sql = random_example['SQL']

    print(f"Evaluating Sample:")
    print('db_id: ',db_id)
    print(f"Question: {nl_query}")
    print(f"Expected SQL: {expected_sql}")

    generated_sql = generate_sql_from_text(nl_prompt)
    print("Generated SQL is:\n",generated_sql)
    #print(f"Generated SQL: {generated_sql}")

    is_valid, validation_msg = validate_sql(generated_sql)
    print(f"SQL Validation: {validation_msg}")
    if not is_valid:
        return

    print("Running expected SQL...")
    print("Expected SQL: ",expected_sql)
    expected_result = execute_query(db_id,expected_sql)
    print(f"Expected Result: {expected_result}")


    print("Running generated SQL...")
    print("Generated SQL: ",generated_sql)
    generated_result = execute_query(db_id,generated_sql)
    print(f"Generated Result: {generated_result}")


    if generated_result == expected_result:
        print("Success: Generated SQL matches expected output!")
    else:
        print("Failure: Mismatch in results.")

# %%
evaluate_bird_benchmark()
# Out:
# Both `max_new_tokens` (=512) and `max_length`(=150) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Evaluating Sample:
# db_id:  toxicology
# Question: Chlorine is in what type of bond?
# Expected SQL: SELECT DISTINCT T1.bond_type FROM bond AS T1 INNER JOIN connected AS T2 ON T1.bond_id = T2.bond_id INNER JOIN atom AS T3 ON T2.atom_id = T3.atom_id WHERE T3.element = 'cl'
# Generated SQL is:
#  SELECT * FROM atom_table WHERE name = 'atom1';
# SQL Validation: Valid SQL
# Running expected SQL...
# Expected SQL:  SELECT DISTINCT T1.bond_type FROM bond AS T1 INNER JOIN connected AS T2 ON T1.bond_id = T2.bond_id INNER JOIN atom AS T3 ON T2.atom_id = T3.atom_id WHERE T3.element = 'cl'
# Executing query in toxicology
# Expected Result: {'result': [('-',)], 'error': None, 'execution_time': 0.06504106521606445}
# Running generated SQL...
# Generated SQL:  SELECT * FROM atom_table WHERE name = 'atom1';
# Executing query in toxicology
# Generated Result: {'result': None, 'error': 'no such table: atom_table', 'execution_time': 0.0004341602325439453}
# Failure: Mismatch in results.
